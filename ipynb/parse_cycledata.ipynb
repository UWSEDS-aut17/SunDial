# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('data/Webplot/Capfade_0SOC-60SOC-p5C.csv',header=None)
df['SOC-low'] = 20
df['SOC-high'] = 60
df['DisRate'] = 0.5

df1 = pd.read_csv('data/Webplot/Capfade_0SOC-100SOC-2C.csv',header=None)
df1['SOC-low'] = 0
df1['SOC-high'] = 100
df1['DisRate'] = 2
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/CapFade_0SOC-100SOC-p5C.csv',header=None)
df1['SOC-low'] = 0
df1['SOC-high'] = 100
df1['DisRate'] = 0.5
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/Capfade_20SOC-80SOC-2C.csv',header=None)
df1['SOC-low'] = 20
df1['SOC-high'] = 80
df1['DisRate'] = 2
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/Capfade_20SOC-80SOC-p5C_2.csv',header=None)
df1['SOC-low'] = 20
df1['SOC-high'] = 80
df1['DisRate'] = .5
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/CapFade_40SOC-60SOC-p5C.csv',header=None)
df1['SOC-low'] = 40
df1['SOC-high'] = 60
df1['DisRate'] = .5
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/Capfade_40SOC-60SOC-2C.csv',header=None)
df1['SOC-low'] = 40
df1['SOC-high'] = 60
df1['DisRate'] = 2
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/CapFade_20SOC-80SOC-p5C.csv',header=None)
df1['SOC-low'] = 20
df1['SOC-high'] = 80
df1['DisRate'] = .5
df = df.append(df1)

df1 = pd.read_csv('data/Webplot/Capfade_40SOC-100SOC-p5C.csv',header=None)
df1['SOC-low'] = 40
df1['SOC-high'] = 100
df1['DisRate'] = .5
df = df.append(df1)

# %%
df = df.rename(columns={0 : 'Cycles', 1 : 'Cap'})
df['Cap'] = df['Cap']/100

# %%
df.to_csv('data/bat_cycle.csv')

# %%
df
# Out:
#         Cycles       Cap  SOC-low  SOC-high  DisRate
# 0     2.546724  1.000081       20        60      0.5
# 1    48.333577  1.008246       20        60      0.5
# 2    80.266972  1.008664       20        60      0.5
# 3    96.233669  1.009083       20        60      0.5
# 4   123.262261  1.012195       20        60      0.5
# 5   138.498456  1.009666       20        60      0.5
# 6   157.282806  1.005690       20        60      0.5
# 7   186.264374  1.001063       20        60      0.5
# 8   202.834854  1.002357       20        60      0.5
# 9   221.358310  1.004550       20        60      0.5
# 10  244.108245  1.002411       20        60      0.5
# 11  263.936170  1.001399       20        60      0.5
# 12  282.198732  1.000563       20        60      0.5
# 13  301.296155  0.996244       20        60      0.5
# 14  313.192909  0.993085       20        60      0.5
# 15  342.174478  0.997587       20        60      0.5
# 16  359.840711  0.997791       20        60      0.5
# 17  380.440882  0.997464       20        60      0.5
# 18  402.230728  0.996641       20        60      0.5
# 19  417.446051  0.996128       20        60      0.5
# 20  439.987271  0.995282       20        60      0.5
# 21  457.456716  0.989918       20        60      0.5
# 22  469.854387  0.986207       20        60      0.5
# 23  483.817420  0.981830       20        60      0.5
# 24  500.618978  0.976759       20        60      0.5
# 25  517.003105  0.979642       20        60      0.5
# 26  536.726672  0.983740       20        60      0.5
# 27  557.389457  0.983756       20        60      0.5
# 28  577.817437  0.982946       20        60      0.5
# 29  595.897374  0.981633       20        60      0.5
# ..         ...       ...      ...       ...      ...
# 12  138.289741  0.942926       40       100      0.5
# 13  164.796546  0.938015       40       100      0.5
# 14  183.849244  0.935587       40       100      0.5
# 15  205.078540  0.933141       40       100      0.5
# 16  226.784900  0.930407       40       100      0.5
# 17  240.873163  0.928740       40       100      0.5
# 18  261.535947  0.925655       40       100      0.5
# 19  285.204228  0.924670       40       100      0.5
# 20  302.861517  0.923707       40       100      0.5
# 21  324.463519  0.921548       40       100      0.5
# 22  352.640044  0.919505       40       100      0.5
# 23  371.424394  0.917830       40       100      0.5
# 24  393.026396  0.915829       40       100      0.5
# 25  417.446051  0.913728       40       100      0.5
# 26  438.839338  0.909585       40       100      0.5
# 27  459.174142  0.906650       40       100      0.5
# 28  480.373623  0.902714       40       100      0.5
# 29  501.573103  0.902073       40       100      0.5
# 30  520.133830  0.901385       40       100      0.5
# 31  539.231252  0.899460       40       100      0.5
# 32  562.836918  0.897166       40       100      0.5
# 33  579.930677  0.896096       40       100      0.5
# 34  604.350332  0.894840       40       100      0.5
# 35  630.648421  0.892608       40       100      0.5
# 36  647.554336  0.892044       40       100      0.5
# 37  672.913208  0.891319       40       100      0.5
# 38  697.332863  0.890881       40       100      0.5
# 39  724.570170  0.891080       40       100      0.5
# 40  748.801982  0.889078       40       100      0.5
# 41  763.078088  0.888255       40       100      0.5
#
# [307 rows x 5 columns]
